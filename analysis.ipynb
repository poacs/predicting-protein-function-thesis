# %%
# results + comparative

# %%
# %pip install matplotlib
# %pip install matploblib scikit-learn

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement matploblib (from versions: none)
# ERROR: No matching distribution found for matploblib
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
epochs = np.arange(1, 11)

model_names = [
    'Baseline Neural Network (3-layers)',
    'Transformer (1-encoder layer)',
    'Transformer (3-encoder layers)',
    'Transformer (4-encoder layers, extra regularization)'
]

# metrics per epoch
losses_base = [0.2140, 0.1447, 0.1282, 0.1197, 0.1145, 0.1109, 0.1078, 0.1052, 0.1029, 0.1008]
accuracy_base = [0.0454, 0.0794, 0.0967, 0.1092, 0.1301, 0.1444, 0.1591, 0.1779, 0.1721, 0.1764]
balanced_acc_base = [0.9417, 0.8898, 0.8543, 0.8659, 0.8630, 0.8637, 0.8853, 0.8733, 0.8863, 0.8979]
precision_base = [0.0733, 0.1812, 0.3405, 0.4254, 0.4086, 0.4446, 0.4928, 0.5347, 0.5525, 0.5675]
recall_base = [0.0394, 0.0834, 0.2100, 0.2264, 0.2885, 0.3483, 0.2977, 0.3733, 0.3721, 0.3180]
f1_base = [0.0454, 0.0982, 0.2450, 0.2743, 0.3220, 0.3577, 0.3486, 0.3965, 0.4088, 0.3782]

losses_1 = [0.8183, 0.5734, 0.5128, 0.4751, 0.4446, 0.4182, 0.3953, 0.3786, 0.3516, 0.3356]
subset_accuracy_1 = [0.0312, 0.0462, 0.0546, 0.0651, 0.0647, 0.0762, 0.0792, 0.0827, 0.0904, 0.0947]
balanced_acc_1 = [0.7657, 0.8470, 0.8652, 0.8754, 0.8843, 0.8913, 0.8976, 0.9031, 0.9097, 0.9145]
precision_1 = [0.1719, 0.3173, 0.3509, 0.3728, 0.3920, 0.4090, 0.4189, 0.4164, 0.4406, 0.4552]
recall_1 = [0.7936, 0.8725, 0.8889, 0.8985, 0.9069, 0.9135, 0.9207, 0.9266, 0.9344, 0.9399]
f1_1 = [0.2628, 0.4376, 0.4725, 0.4951, 0.5144, 0.5310, 0.5420, 0.5425, 0.5653, 0.5794]

losses_3 = [0.7513, 0.5745, 0.5310, 0.4868, 0.4666, 0.4334, 0.4008, 0.3841, 0.3644, 0.3574]
subset_accuracy_3 = [0.0302, 0.0461, 0.0523, 0.0606, 0.0647, 0.0692, 0.0732, 0.0819, 0.0815, 0.0917]
balanced_acc_3 = [0.7882, 0.8484, 0.8603, 0.8749, 0.8793, 0.8891, 0.8968, 0.9011, 0.9068, 0.9095]
precision_3 = [0.1899, 0.3043, 0.3279, 0.3622, 0.3664, 0.3875, 0.4035, 0.4145, 0.4264, 0.4176]
recall_3 = [0.8199, 0.8731, 0.8830, 0.8997, 0.9011, 0.9136, 0.9190, 0.9230, 0.9311, 0.9327]
f1_3 = [0.2907, 0.4241, 0.4494, 0.4850, 0.4905, 0.5124, 0.5293, 0.5402, 0.5527, 0.5468]

losses_4_reg = [0.7953, 0.5720, 0.5237, 0.4807, 0.4386, 0.3971, 0.3706, 0.3381, 0.3138, 0.2996]
subset_accuracy_4_reg = [0.0230, 0.0486, 0.0577, 0.0664, 0.0748, 0.0894, 0.0982, 0.1094, 0.1147, 0.1258]
balanced_acc_4_reg = [0.7783, 0.8539, 0.8691, 0.8817, 0.8912, 0.9011, 0.9090, 0.9150, 0.9220, 0.9255]
precision_4_reg = [0.2199, 0.3683, 0.3965, 0.4206, 0.4475, 0.4693, 0.4913, 0.5197, 0.5315, 0.5402]
recall_4_reg = [0.7721, 0.8601, 0.8729, 0.8890, 0.8965, 0.9070, 0.9154, 0.9228, 0.9353, 0.9411]
f1_4_reg = [0.3235, 0.4828, 0.5107, 0.5356, 0.5599, 0.5821, 0.6018, 0.6253, 0.6381, 0.6474]

losses = [
    [0.2140, 0.1447, 0.1282, 0.1197, 0.1145, 0.1109, 0.1078, 0.1052, 0.1029, 0.1008],
    [0.8183, 0.5734, 0.5128, 0.4751, 0.4446, 0.4182, 0.3953, 0.3786, 0.3516, 0.3356],
    [0.7513, 0.5745, 0.5310, 0.4868, 0.4666, 0.4334, 0.4008, 0.3841, 0.3644, 0.3574],
    [0.7953, 0.5720, 0.5237, 0.4807, 0.4386, 0.3971, 0.3706, 0.3381, 0.3138, 0.2996]
]

subset_accuracies = [
    [0.0454, 0.0794, 0.0967, 0.1092, 0.1301, 0.1444, 0.1591, 0.1779, 0.1721, 0.1764],
    [0.0312, 0.0462, 0.0546, 0.0651, 0.0647, 0.0762, 0.0792, 0.0827, 0.0904, 0.0947],
    [0.0302, 0.0461, 0.0523, 0.0606, 0.0647, 0.0692, 0.0732, 0.0819, 0.0815, 0.0917],
    [0.0230, 0.0486, 0.0577, 0.0664, 0.0748, 0.0894, 0.0982, 0.1094, 0.1147, 0.1258]
]

balanced_accuracies = [
    [0.9417, 0.8898, 0.8543, 0.8659, 0.8630, 0.8637, 0.8853, 0.8733, 0.8863, 0.8979],
    [0.7657, 0.8470, 0.8652, 0.8754, 0.8843, 0.8913, 0.8976, 0.9031, 0.9097, 0.9145],
    [0.7882, 0.8484, 0.8603, 0.8749, 0.8793, 0.8891, 0.8968, 0.9011, 0.9068, 0.9095],
    [0.7783, 0.8539, 0.8691, 0.8817, 0.8912, 0.9011, 0.9090, 0.9150, 0.9220, 0.9255]
]

precision = [
    [0.0733, 0.1812, 0.3405, 0.4254, 0.4086, 0.4446, 0.4928, 0.5347, 0.5525, 0.5675],
    [0.1719, 0.3173, 0.3509, 0.3728, 0.3920, 0.4090, 0.4189, 0.4164, 0.4406, 0.4552],
    [0.1899, 0.3043, 0.3279, 0.3622, 0.3664, 0.3875, 0.4035, 0.4145, 0.4264, 0.4176],
    [0.2199, 0.3683, 0.3965, 0.4206, 0.4475, 0.4693, 0.4913, 0.5197, 0.5315, 0.5402]
]

recall = [
    [0.0394, 0.0834, 0.2100, 0.2264, 0.2885, 0.3483, 0.2977, 0.3733, 0.3721, 0.3180],
    [0.7936, 0.8725, 0.8889, 0.8985, 0.9069, 0.9135, 0.9207, 0.9266, 0.9344, 0.9399],
    [0.8199, 0.8731, 0.8830, 0.8997, 0.9011, 0.9136, 0.9190, 0.9230, 0.9311, 0.9327],
    [0.7721, 0.8601, 0.8729, 0.8890, 0.8965, 0.9070, 0.9154, 0.9228, 0.9353, 0.9411]
]

f1_scores = [
    [0.0454, 0.0982, 0.2450, 0.2743, 0.3220, 0.3577, 0.3486, 0.3965, 0.4088, 0.3782],
    [0.2628, 0.4376, 0.4725, 0.4951, 0.5144, 0.5310, 0.5420, 0.5425, 0.5653, 0.5794],
    [0.2907, 0.4241, 0.4494, 0.4850, 0.4905, 0.5124, 0.5293, 0.5402, 0.5527, 0.5468],
    [0.3235, 0.4828, 0.5107, 0.5356, 0.5599, 0.5821, 0.6018, 0.6253, 0.6381, 0.6474]
]

# helper to plot metric across models
def plot_metric(metric_list, ylabel, title):
    plt.figure()
    for data, name in zip(metric_list, model_names):
        plt.plot(epochs, data, label=name)
    plt.title(f'Comparison Across Models: {title}')
    plt.xlabel('Epoch')
    plt.ylabel(ylabel)
    plt.legend()
    plt.show()

# generate plots
plot_metric(losses, 'Loss', 'Training Loss')
plot_metric(subset_accuracies, 'Subset Accuracy', 'Training Subset Accuracy')
plot_metric(balanced_accuracies, 'Balanced Accuracy', 'Training Balanced Accuracy')
plot_metric(precision, 'Precision', 'Precision')
plot_metric(recall, 'Recall', 'Recall')
plot_metric(f1_scores, 'F1 Score', 'F1 Score')

# %%
from sklearn.metrics import confusion_matrix
import torch
from IPython.display import display

# %%
# confusion counts for final epoch (epoch 10) for first 10 classes

labels = [
    "3-phosphoinositide-dependent protein kinase activity [GO:0004676]",
    "AMP-activated protein kinase activity [GO:0004679]",
    "ATP binding [GO:0005524]",
    "ATP hydrolysis activity [GO:0016887]",
    "DNA binding [GO:0003677]",
    "DNA-binding transcription activator activity, RNA polymerase II-specific [GO:0001228]",
    "DNA-binding transcription factor activity [GO:0003700]",
    "DNA-binding transcription factor activity, RNA polymerase II-specific [GO:0000981]",
    "DNA-binding transcription repressor activity, RNA polymerase II-specific [GO:0001227]",
    "DNA-dependent protein kinase activity [GO:0004677]"
]

conf_baseline = {
    'TN': [10261, 10264, 8961, 10118, 9610, 10000, 10037, 9067, 10274, 10266],
    'FP': [   34,    29,  102,     5,    0,    65,    17,   233,     0,    28],
    'FN': [  128,   143,  529,   284,  929,   348,   471,   157,   266,   136],
    'TP': [  117,   104,  948,   133,    1,   127,    15,  1083,     0,   110]
}

conf_1 = {
    'TN': [10130, 10116, 8775, 9882, 7107, 9040, 8937, 9003, 9036, 10129],
    'FP': [  165,   177,  288,  241, 2503, 1025, 1117,  297, 1238,  165],
    'FN': [    0,     0,   57,    3,   94,    2,    1,    7,    0,    0],
    'TP': [  245,   247, 1420,  414,  836,  473,  485, 1233,  266,  246]
}

conf_3 = {
    'TN': [10102, 10093, 8779, 9887, 6622, 9122, 8993, 9034, 9217, 10101],
    'FP': [  193,   200,  284,  236, 2988,  943, 1061,  266, 1057,  193],
    'FN': [    0,     0,   41,    4,   50,    3,    4,   11,    3,    0],
    'TP': [  245,   247, 1436,  413,  880,  472,  482, 1229,  263,  246]
}

conf_4_reg = {
    'TN': [10262, 10257, 8820, 9959, 7527, 9127, 9044, 9046, 9310, 10261],
    'FP': [   33,    36,  243,  164, 2083,  938, 1010,  254,  964,   33],
    'FN': [    5,     4,   41,    6,  125,    5,    4,   12,    7,    6],
    'TP': [  240,   243, 1436,  411,  805,  470,  482, 1228,  259,  240]
}

df_base = pd.DataFrame(conf_baseline, index=labels)
df_1 = pd.DataFrame(conf_1, index=labels)
df_3 = pd.DataFrame(conf_3, index=labels)
df_4_reg = pd.DataFrame(conf_4_reg, index=labels)

# plot heatmaps
configs = [
    (df_base, "Heatmap of Confusion Matrix Counts (Epoch 10) -- Baseline Neural Network"),
    (df_1, "Heatmap of Confusion Matrix Counts (Epoch 10) -- 1-Encoder Layer Transformer"),
    (df_3, "Heatmap of Confusion Matrix Counts (Epoch 10) -- 3-Encoder Layer Transformer"),
    (df_4_reg, "Heatmap of Confusion Matrix Counts (Epoch 10) -- 4-Encoder Layer Transformer w/ Extra Regularization")
]

for df, title in configs:
    plt.figure(figsize=(12, 6))
    plt.imshow(df.values, aspect="auto", interpolation="nearest")
    plt.colorbar(label="Count")
    plt.xticks(np.arange(len(df.columns)), df.columns, rotation=0)
    plt.yticks(np.arange(len(labels)), labels, fontsize=8)
    plt.title(title)
    plt.xlabel("Metric")
    plt.ylabel("GO Term (First 10 Classes)")
    plt.tight_layout()
    plt.show()
